# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # covid

# %%
dfcovid = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\covid_toy.csv")

# %%
dfcovid
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
dfcovid.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
dfcovid.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
dfcovid.sample()
# Out:
#     age gender  fever   cough       city has_covid
# 20   12   Male   98.0  Strong  Bangalore        No

# %%
dfcovid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
dfcovid.size
# Out:
# 600

# %%
dfcovid.shape
# Out:
# (100, 6)

# %%
dfcovid.loc[:3,['age','gender','has_covid']]
# Out:
#    age  gender has_covid
# 0   60    Male        No
# 1   27    Male       Yes
# 2   42    Male        No
# 3   31  Female        No

# %%
dfcovid.loc[1:5,['age','gender','has_covid']]
# Out:
#    age  gender has_covid
# 1   27    Male       Yes
# 2   42    Male        No
# 3   31  Female        No
# 4   65  Female        No
# 5   84  Female       Yes

# %%
dfcovid.iloc[1:5,:3]
# Out:
#    age  gender  fever
# 1   27    Male  100.0
# 2   42    Male  101.0
# 3   31  Female   98.0
# 4   65  Female  101.0

# %%
dfcovid.iloc[1:5,2:4]
# Out:
#    fever cough
# 1  100.0  Mild
# 2  101.0  Mild
# 3   98.0  Mild
# 4  101.0  Mild

# %%
dfcovid.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
dfcovid.ndim
# Out:
# 2

# %%
dfcovid.empty
# Out:
# False

# %%
dfcovid.info
# Out:
# <bound method DataFrame.info of     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]>

# %%
dfcovid.values
# Out:
# array([[60, 'Male', 103.0, 'Mild', 'Kolkata', 'No'],
#        [27, 'Male', 100.0, 'Mild', 'Delhi', 'Yes'],
#        [42, 'Male', 101.0, 'Mild', 'Delhi', 'No'],
#        [31, 'Female', 98.0, 'Mild', 'Kolkata', 'No'],
#        [65, 'Female', 101.0, 'Mild', 'Mumbai', 'No'],
#        [84, 'Female', nan, 'Mild', 'Bangalore', 'Yes'],
#        [14, 'Male', 101.0, 'Strong', 'Bangalore', 'No'],
#        [20, 'Female', nan, 'Strong', 'Mumbai', 'Yes'],
#        [19, 'Female', 100.0, 'Strong', 'Bangalore', 'No'],
#        [64, 'Female', 101.0, 'Mild', 'Delhi', 'No'],
#        [75, 'Female', nan, 'Mild', 'Delhi', 'No'],
#        [65, 'Female', 98.0, 'Mild', 'Mumbai', 'Yes'],
#        [25, 'Female', 99.0, 'Strong', 'Kolkata', 'No'],
#        [64, 'Male', 102.0, 'Mild', 'Bangalore', 'Yes'],
#        [51, 'Male', 104.0, 'Mild', 'Bangalore', 'No'],
#        [70, 'Male', 103.0, 'Strong', 'Kolkata', 'Yes'],
#        [69, 'Female', 103.0, 'Mild', 'Kolkata', 'Yes'],
# ...

# %%
dfcovid.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
dfcovid=dfcovid.copy()
dfcovid
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
p=dfcovid.sort_values("fever")

# %%
p
# Out:
#     age  gender  fever   cough     city has_covid
# 99   10  Female   98.0  Strong  Kolkata       Yes
# 98    5  Female   98.0  Strong   Mumbai        No
# 33   26  Female   98.0    Mild  Kolkata        No
# 53   83    Male   98.0    Mild    Delhi       Yes
# 58   23    Male   98.0  Strong   Mumbai       Yes
# ..  ...     ...    ...     ...      ...       ...
# 29   34  Female    NaN  Strong   Mumbai       Yes
# 41   82    Male    NaN    Mild  Kolkata       Yes
# 56   71    Male    NaN  Strong  Kolkata        No
# 91   38    Male    NaN    Mild    Delhi       Yes
# 94   79    Male    NaN  Strong  Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
x=dfcovid['age'].astype(int)
print(x)
# Out:
# 0     60
# 1     27
# 2     42
# 3     31
# 4     65
#       ..
# 95    12
# 96    51
# 97    20
# 98     5
# 99    10
# Name: age, Length: 100, dtype: int32

# %%
x=dfcovid['age'].add(4)
x
# Out:
# 0     64
# 1     31
# 2     46
# 3     35
# 4     69
#       ..
# 95    16
# 96    55
# 97    24
# 98     9
# 99    14
# Name: age, Length: 100, dtype: int64

# %% [markdown]
# # placement

# %%
dfplcmt = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\placement.csv")
dfplcmt
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
dfplcmt.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
dfplcmt.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
dfplcmt.sample()
# Out:
#     cgpa  resume_score  placed
# 28  7.46          7.67       1

# %%
dfplcmt.size
# Out:
# 300

# %%
dfplcmt.shape
# Out:
# (100, 3)

# %%
dfplcmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
dfplcmt.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
dfplcmt.ndim
# Out:
# 2

# %%
dfplcmt.empty
# Out:
# False

# %%
dfplcmt.info
# Out:
# <bound method DataFrame.info of     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]>

# %%
dfplcmt.dtypes
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
dfplcmt.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
dfplcmt.loc[2:3,['cgpa','placed']]
# Out:
#    cgpa  placed
# 2  8.27       1
# 3  6.88       1

# %%
dfplcmt.iloc[2:6,:3]
# Out:
#    cgpa  resume_score  placed
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1
# 5  8.77          6.19       1

# %%
dfplcmt=dfplcmt.copy()
dfplcmt
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
dfplcmt.sort_values("resume_score")
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
x=dfplcmt.astype(int)
print(x)
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
x=dfplcmt.add(10)
print(x)
# Out:
#      cgpa  resume_score  placed
# 0   18.14         16.52      11
# 1   16.17         15.17      10
# 2   18.27         18.86      11
# 3   16.88         17.27      11
# 4   17.52         17.30      11
# ..    ...           ...     ...
# 95  16.33         16.38      10
# 96  18.23         17.76      11
# 97  16.65         17.78      10
# 98  18.14         15.63      11
# 99  16.09         16.61      10
#
# [100 rows x 3 columns]

# %% [markdown]
# # titanic

# %%
dftitanic = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\titanic.csv")
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
dftitanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
dftitanic.sample()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 263         1155         1       3  Klasen, Miss. Gertrud Emilia  female  1.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 263      1      1  350405  12.1833   NaN        S

# %%
dftitanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dftitanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
dftitanic.shape
# Out:
# (418, 12)

# %%
dftitanic.size
# Out:
# 5016

# %%
dftitanic.values
# Out:
# array([[892, 0, 3, ..., 7.8292, nan, 'Q'],
#        [893, 1, 3, ..., 7.0, nan, 'S'],
#        [894, 0, 2, ..., 9.6875, nan, 'Q'],
#        ...,
#        [1307, 0, 3, ..., 7.25, nan, 'S'],
#        [1308, 0, 3, ..., 8.05, nan, 'S'],
#        [1309, 0, 3, ..., 22.3583, nan, 'C']], dtype=object)

# %%
dftitanic.empty
# Out:
# False

# %%
dftitanic.axes
# Out:
# [RangeIndex(start=0, stop=418, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
dftitanic.ndim
# Out:
# 2

# %%
dftitanic.iloc[2:10,1:4]
# Out:
#    Survived  Pclass                                          Name
# 2         0       2                     Myles, Mr. Thomas Francis
# 3         0       3                              Wirz, Mr. Albert
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5         0       3                    Svensson, Mr. Johan Cervin
# 6         1       3                          Connolly, Miss. Kate
# 7         0       2                  Caldwell, Mr. Albert Francis
# 8         1       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9         0       3                       Davies, Mr. John Samuel

# %%
dftitanic.loc[2:10,['PassengerId', 'Survived', 'Pclass']]
# Out:
#     PassengerId  Survived  Pclass
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3

# %%
dftitanic['PassengerId'].astype(int)
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int32

# %%
dftitanic['PassengerId'].add(5)
# Out:
# 0       897
# 1       898
# 2       899
# 3       900
# 4       901
#        ...
# 413    1310
# 414    1311
# 415    1312
# 416    1313
# 417    1314
# Name: PassengerId, Length: 418, dtype: int64

# %%
dftitanic.sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %%
dftitanic=dftitanic.copy()
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # tips

# %%
dftips=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\tips.csv")
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dftips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dftips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
dftips.sample()
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2

# %%
dftips.size
# Out:
# 1708

# %%
dftips.shape
# Out:
# (244, 7)

# %%
dftips.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
dftips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
dftips.axes
# Out:
# [RangeIndex(start=0, stop=244, step=1),
#  Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')]

# %%
dftips.ndim
# Out:
# 2

# %%
dftips.empty
# Out:
# False

# %%
dftips.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
dftips.loc[1:4,['sex', 'smoker', 'day']]
# Out:
#       sex smoker  day
# 1    Male     No  Sun
# 2    Male     No  Sun
# 3    Male     No  Sun
# 4  Female     No  Sun

# %%
dftips.iloc[1:4,3:6]
# Out:
#   smoker  day    time
# 1     No  Sun  Dinner
# 2     No  Sun  Dinner
# 3     No  Sun  Dinner

# %%
dftips=dftips.copy()
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dftips['tip'].astype(int)
# Out:
# 0      1
# 1      1
# 2      3
# 3      3
# 4      3
#       ..
# 239    5
# 240    2
# 241    2
# 242    1
# 243    3
# Name: tip, Length: 244, dtype: int32

# %%
dftips['tip'].add(5)
# Out:
# 0       6.01
# 1       6.66
# 2       8.50
# 3       8.31
# 4       8.61
#        ...
# 239    10.92
# 240     7.00
# 241     7.00
# 242     6.75
# 243     8.00
# Name: tip, Length: 244, dtype: float64

# %%
dftips.sort_values("")

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 63  8.65          7.58       1

# %%
df.describe() # statistically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info() # data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\covid_toy.csv")
df.loc[2:5,['gender','cough','has_covid']]
# Out:
#    gender cough has_covid
# 2    Male  Mild        No
# 3  Female  Mild        No
# 4  Female  Mild        No
# 5  Female  Mild       Yes

# %%
df.iloc[:5,:3]
# Out:
#    age  gender  fever
# 0   60    Male  103.0
# 1   27    Male  100.0
# 2   42    Male  101.0
# 3   31  Female   98.0
# 4   65  Female  101.0

# %%
s=df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
b=df.empty
b
# Out:
# False

# %%
i=df.ndim  # gives number of axes(dimenions)
i
# Out:
# 2

# %%
t=df.shape # n(rows),n(columns)
t
# Out:
# (100, 6)

# %%
d=df.size # n(rows)*n(columns)
d
# Out:
# 600

# %%
a=df.values # get a numpy array
a
# Out:
# array([[60, 'Male', 103.0, 'Mild', 'Kolkata', 'No'],
#        [27, 'Male', 100.0, 'Mild', 'Delhi', 'Yes'],
#        [42, 'Male', 101.0, 'Mild', 'Delhi', 'No'],
#        [31, 'Female', 98.0, 'Mild', 'Kolkata', 'No'],
#        [65, 'Female', 101.0, 'Mild', 'Mumbai', 'No'],
#        [84, 'Female', nan, 'Mild', 'Bangalore', 'Yes'],
#        [14, 'Male', 101.0, 'Strong', 'Bangalore', 'No'],
#        [20, 'Female', nan, 'Strong', 'Mumbai', 'Yes'],
#        [19, 'Female', 100.0, 'Strong', 'Bangalore', 'No'],
#        [64, 'Female', 101.0, 'Mild', 'Delhi', 'No'],
#        [75, 'Female', nan, 'Mild', 'Delhi', 'No'],
#        [65, 'Female', 98.0, 'Mild', 'Mumbai', 'Yes'],
#        [25, 'Female', 99.0, 'Strong', 'Kolkata', 'No'],
#        [64, 'Male', 102.0, 'Mild', 'Bangalore', 'Yes'],
#        [51, 'Male', 104.0, 'Mild', 'Bangalore', 'No'],
#        [70, 'Male', 103.0, 'Strong', 'Kolkata', 'Yes'],
#        [69, 'Female', 103.0, 'Mild', 'Kolkata', 'Yes'],
# ...

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Regex\\New folder\\placement.csv")
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
x=df.astype(int) #type conversion
# x=df['cgpa'].astype(int)  --> for any one column 
x
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
t=df.add(4)
# df['cgpa'].add(4) --> for individual column
t
# Out:
#      cgpa  resume_score  placed
# 0   12.14         10.52       5
# 1   10.17          9.17       4
# 2   12.27         12.86       5
# 3   10.88         11.27       5
# 4   11.52         11.30       5
# ..    ...           ...     ...
# 95  10.33         10.38       4
# 96  12.23         11.76       5
# 97  10.65         11.78       4
# 98  12.14          9.63       5
# 99  10.09         10.61       4
#
# [100 rows x 3 columns]
